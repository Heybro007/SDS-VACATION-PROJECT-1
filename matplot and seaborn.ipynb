# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [raw]
# functional method to create plot

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
#if not on jupyter use plt.show()
# Out:
# Text(0.5, 1.0, 'Title')

# %%
print('string')
# Out:
# string

# %%
plt.plot(x,y,'r-')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#object oriented method to plot

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.99,0.99])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('ECO')

axes2.plot(y,x)
axes2.set_title('FRIENDLY')
# Out:
# Text(0.5, 1.0, 'FRIENDLY')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.1,0.1,0.7,0.6])

axes1.plot(x,y)
axes1.set_title('LIFE')

axes2.plot(y,x)
axes2.set_title('IS LIT')
# Out:
# Text(0.5, 1.0, 'IS LIT')

# %%
fig,axes=plt.subplots(nrows=3,ncols=5)

#axes.plot(x,y)

plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title('First Plot')
axes[1].plot(y,x)
axes[1].set_title('Second Plot')
plt.tight_layout()

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002790788E148>,
# ...
#       dtype=object)

# %%
#FIGURE SIZE AND DPI

# %%
fig=plt.figure(figsize=(8,2))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(8,2))

axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig.savefig('my_picture.png')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x**5,x,label='X raised to 5')
ax.legend()

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x**5,x,label='X raised to 5')
ax.legend(loc=10)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x**5,x,label='X raised to 5')
ax.legend(loc=(0.1,0.1))

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='violet')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='violet',linewidth=20,linestyle='steps')
# Out:
# c:\users\ayush mishra\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='violet',lw=2,ls='--',marker='+',markersize=20)
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %%
plt.scatter(x,y)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 6., 15., 17.,  7., 15., 10.,  5.,  6.,  7., 12.]),
#  array([  5. , 104.2, 203.4, 302.6, 401.8, 501. , 600.2, 699.4, 798.6,
#         897.8, 997. ]),
#  <a list of 10 Patch objects>)

# %%
data=[np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(data,vert=True,patch_artist=True);

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde=False,bins=100)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.pairplot(tips)
